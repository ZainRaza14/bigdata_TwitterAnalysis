# %%
import time

from sentimentalAnalysis.sentimentalAnalysis_Local import sent_Analysis

from utils.utils import *

import pandas as pd

# %%
#file = "data/json/tweets.json"

#convert_JsontoCSV(file)

# %%
data = pd.read_csv("data/csv/tweets.csv")

# %%
data.head()
# Out:
#       screen_name  followers  rt  \
# 0      Jeremy972i        453   6
# 1       _Aldanabg        714   0
# 2       GamzeSart       1273  39
# 3       GamzeSart       1273  94
# 4  cybersec_feeds       4446  23
#
#                                                 text
# 0  b'RT @marcusborba: 63% of #CEOs agree, #AI wil...
# 1  b'Lawfare y el manejo d la bigdata son las nue...
# 2  b'RT @MikeQuindazzi: Top #AI risks for busines...
# 3  b'RT @MikeQuindazzi: #AI will contribute $15.7...
# 4  b'RT @Paula_Piccard: 6 Key Requirements for #I...

# %%
textsTweet_temp = data['text']

# %%
textsTweet = list(textsTweet_temp)

# %%
print(len(textsTweet))
# Out:
# 3303

# %%
c_Words = cleanWords(textsTweet)

# %%
words_Pt = get_TopWords(c_Words)

# %%
print(words_Pt)
# Out:
# +------------+-------+
# | Words      | Count |
# +------------+-------+
# | data       |   542 |
# | amp        |   423 |
# | learning   |   359 |
# | stratadata |   301 |
# | bigdata    |   284 |
# +------------+-------+

# %%
tweets_Cleaned = []

# %%
for text in textsTweet:
    tweets_Cleaned.append(getCleaned_Tweets(text))

# %%
print(tweets_Cleaned)
# Out:
# ['marcusborba ceo agree greater impact internet', 'lawfare manejo bigdata son la nuevas herramientas quiebran democracia ante bombardeaban una pla', 'mikequindazzi top risk business amp technology leader pwc via mikequindazzi machinelearning deeplearning nlg big', 'mikequindazzi contribute trillion global economy pwc via mikequindazzi machinelearning deepl', 'paula piccard key requirement iot success cybersecurity bigdata analytics sensor digitaltransformation dataviz secur', 'maxjcm common cybersecurity mistake made with cybersecurity bigdata predictiveanalytics chuckdbrooks mcl', 'ronald vanloon difference surfaceweb deepweb darkweb infographics glwebeu nread', 'iainljbrown artificial intelligence pose new threat equal employment opportunity forbes nread', 'ronald vanloon way you use quantum technology every day nby dominicwalliman antgrasso iot bigdata artificialintelligence', 'the single market remains decisive power', 'ronald vanloon difference surfaceweb deepweb darkweb infographics glwebeu nread', 'idea repurpose content require very little effort', 'claudiomkd difference surfaceweb deepweb darkweb infographics glwebeu nread art', 'ronald vanloon difference surfaceweb deepweb darkweb infographics glwebeu nread', 'ronald vanloon difference surfaceweb deepweb darkweb infographics glwebeu nread', 'why datawarehouse becoming dataservice our blog question systemsarchitects', 'pydata keep new development numfocus sponsored project join monthly email newsletter', 'nihalertugrul natgeo japanese scientist create visualize thought nvia wef artificialintelligence machinelea', 'marcusborba ceo agree greater impact internet', 'ronald vanloon difference surfaceweb deepweb darkweb infographics glwebeu nread', 'marcusborba ceo agree greater impact internet', 'ronald vanloon difference surfaceweb deepweb darkweb infographics glwebeu nread', 'salomonoli want see deeplearning iot bigdata via', 'pulipaka new game theory innovation influencing reinforcementlearning bigdata analytics datascience machinelear', 'clark robotics futureofwork global ceo concern availability talent risen pwc via mikequindazzi', 'craigbrownphd azure infrastructure service iaa every workload', 'heading sgfintechfest keen demo microsoft booth today', 'five benefit big data analytics and how company can get started bigdata bigdataanalytics company via', 'want see deeplearning iot bigdata via', 'pulipaka what bigdata analytics datascience machinelearning reinforcementlearning iot iiot pytorch python', 'ume kyd pursuit dream innovation ndiscover insightful information data nfind new smartdata frontier vi', 'pulipaka what bigdata analytics datascience machinelearning reinforcementlearning iot iiot pytorch python', 'pulipaka new game theory innovation influencing reinforcementlearning bigdata analytics datascience machinelear', 'pulipaka tiobe programming index nov getting close java bigdata analytics datascience iot iiot cpp pytor', 'pulipaka dotnetcore jupyter notebook available today bigdata analytics hadoop apachespark datascience machinel', 'pulipaka running your model browser using tensorflowjs onnxjs bigdata analytics datascience machinelearning', 'pulipaka knowledge quadrant machine learning bigdata analytics datascience machinelearning iot iiot pytorch python', 'millennials boomer zoomers bitcoin stock ethereum instablockchain instacrypto btcnews monero', 'difference surfaceweb deepweb darkweb infographics glwebeu nread', 'bigdata joe step starting your own business nvia ravikikan mikequindazzi datascience bigdata infographics tech marketin', 'microsoft warnerbros ont une technologie verre quartz capable stocker plusieurs centaines', 'pulipaka tiobe programming index nov getting close java bigdata analytics datascience iot iiot cpp pytor', 'pulipaka java deeplearning cookbook released bigdata analytics datascience machinelearning iot iiot pytorch python', 'pulipaka dotnetcore jupyter notebook available today bigdata analytics hadoop apachespark datascience machin ...

# %%
start_time = time.time()

sent_Analysis(tweets_Cleaned)

print(" ")

print("--- It took %s seconds to run the program ---" % (time.time() - start_time))
# Out:
#  Total No. positive tweets = 1601 Percentage = 48.471086890705415
#
#  Total No. of neutral tweets  = 1476 Percentage = 44.6866485013624
#
#  Total No. of negative tweets = 226 Percentage = 6.842264607932179
#
# --- It took 1.1649198532104492 seconds to run the program ---
